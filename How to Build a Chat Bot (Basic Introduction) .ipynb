# %% [markdown]
# ### Import Libraries

# %%
#Guilbeault 2021
#People Analytics Tutorial 
#How to build your own chat bot (An Introduction)

import warnings
warnings.filterwarnings('ignore')

import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
from keras.models import load_model
import random

import tkinter
from tkinter import *

#This code is adapted from the following source
#https://towardsdatascience.com/how-to-create-a-chatbot-with-python-deep-learning-in-less-than-an-hour-56a063bdfc44

#A key lesson: most techniques can be readily built for you and acquired online!
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dougl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\dougl\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### Load in custom manual response type and responses

# %%
intents = {"intents": [
        {"tag": "greeting",
         "patterns": ["Hi there", "How are you", "Is anyone there?","Hey","Hola", "Hello", "Good day"],
         "responses": ["Hello, thanks for asking", "Good to see you again", "Hi there, how can I help?"],
         "context": [""]
        },
        {"tag": "goodbye",
         "patterns": ["Bye", "See you later", "Goodbye", "Nice chatting to you, bye", "Till next time"],
         "responses": ["See you!", "Have a nice day", "Bye! Come back again soon."],
         "context": [""]
        },
        {"tag": "thanks",
         "patterns": ["Thanks", "Thank you", "That's helpful", "Awesome, thanks", "Thanks for helping me"],
         "responses": ["Happy to help!", "Any time!", "My pleasure"],
         "context": [""]
        },
        {"tag": "noanswer",
         "patterns": [],
         "responses": ["Sorry, can't understand you", "Please give me more info", "Not sure I understand"],
         "context": [""]
        },
        {"tag": "options",
         "patterns": ["How you could help me?", "What you can do?", "What help you provide?", "How you can be helpful?", "What support is offered"],
         "responses": ["I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies", "Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies"],
         "context": [""]
        },
        {"tag": "adverse_drug",
         "patterns": ["How to check Adverse drug reaction?", "Open adverse drugs module", "Give me a list of drugs causing adverse behavior", "List all drugs suitable for patient with adverse reaction", "Which drugs dont have adverse reaction?" ],
         "responses": ["Navigating to Adverse drug reaction module"],
         "context": [""]
        },
        {"tag": "blood_pressure",
         "patterns": ["Open blood pressure module", "Task related to blood pressure", "Blood pressure data entry", "I want to log blood pressure results", "Blood pressure data management" ],
         "responses": ["Navigating to Blood Pressure module"],
         "context": [""]
        },
        {"tag": "blood_pressure_search",
         "patterns": ["I want to search for blood pressure result history", "Blood pressure for patient", "Load patient blood pressure result", "Show blood pressure results for patient", "Find blood pressure results by ID" ],
         "responses": ["Please provide Patient ID", "Patient ID?"],
         "context": ["search_blood_pressure_by_patient_id"]
        },
        {"tag": "search_blood_pressure_by_patient_id",
         "patterns": [],
         "responses": ["Loading Blood pressure result for Patient"],
         "context": [""]
        },
        {"tag": "pharmacy_search",
         "patterns": ["Find me a pharmacy", "Find pharmacy", "List of pharmacies nearby", "Locate pharmacy", "Search pharmacy" ],
         "responses": ["Please provide pharmacy name"],
         "context": ["search_pharmacy_by_name"]
        },
        {"tag": "search_pharmacy_by_name",
         "patterns": [],
         "responses": ["Loading pharmacy details"],
         "context": [""]
        },
        {"tag": "hospital_search",
         "patterns": ["Lookup for hospital", "Searching for hospital to transfer patient", "I want to search hospital data", "Hospital lookup for patient", "Looking up hospital details" ],
         "responses": ["Please provide hospital name or location"],
         "context": ["search_hospital_by_params"]
        },
        {"tag": "search_hospital_by_params",
         "patterns": [],
         "responses": ["Please provide hospital type"],
         "context": ["search_hospital_by_type"]
        },
        {"tag": "search_hospital_by_type",
         "patterns": [],
         "responses": ["Loading hospital details"],
         "context": [""]
        }
   ]
}

# %% [markdown]
# ### Initialize Basic Structure of Language Model

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']

for intents in intents['intents']:
    for pattern in intents['patterns']:

        # take each word and tokenize it
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # adding documents
        documents.append((w, intents['tag']))

        # adding classes to our class list
        if intents['tag'] not in classes:
            classes.append(intents['tag'])

            words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
classes = sorted(list(set(classes)))

print (len(documents), "documents")
print (len(classes), "classes", classes)
print (len(words), "unique lemmatized words", words)

#Save language model 
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 90 unique lemmatized words ["'s", ',', 'Hospital', 'I', 'Looking', 'Searching', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'details', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %% [markdown]
# ### Build Model Training Data

# %%
# initializing training data
training = []
output_empty = [0] * len(classes)
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
    
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created

# %% [markdown]
# ### Build Model on Test Data

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output response with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)

#Save your Model! 
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# Epoch 1/200
# 10/10 [==============================] - 2s 3ms/step - loss: 2.2739 - accuracy: 0.0500
# Epoch 2/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.2330 - accuracy: 0.1108
# Epoch 3/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1591 - accuracy: 0.3000
# Epoch 4/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.0329 - accuracy: 0.2695
# Epoch 5/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.0383 - accuracy: 0.2116
# Epoch 6/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.9086 - accuracy: 0.4306
# Epoch 7/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.9608 - accuracy: 0.2106
# Epoch 8/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5531 - accuracy: 0.5845
# Epoch 9/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5308 - accuracy: 0.5957
# Epoch 10/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2947 - accuracy: 0.6372
# Epoch 11/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3203 - accuracy: 0.5669
# Epoch 12/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1970 - accuracy: 0.6744
# Epoch 13/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9164 - accuracy: 0.7452
# Epoch 14/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8199 - accuracy: 0.8041
# Epoch 15/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9829 - accuracy: 0.7182
# Epoch 16/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8150 - accuracy: 0.8037
# Epoch 17/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7576 - accuracy: 0.7676
# Epoch 18/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7901 - accuracy: 0.7416
# Epoch 19/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6073 - accuracy: 0.8777
# Epoch 20/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6826 - accuracy: 0.8175
# Epoch 21/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3735 - accuracy: 0.9556
# Epoch 22/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3924 - accuracy: 0.9202
# Epoch 23/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4629 - accuracy: 0.8732
# Epoch 24/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2353 - accuracy: 0.9780
# Epoch 25/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4337 - accuracy: 0.9048
# Epoch 26/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2727 - accuracy: 0.9129
# Epoch 27/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3605 - accuracy: 0.8919
# Epoch 28/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4587 - accuracy: 0.8203
# Epoch 29/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3563 - accuracy: 0.9455
# Epoch 30/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3077 - accuracy: 0.9502
# Epoch 31/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2917 - accuracy: 0.9563
# Epoch 32/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2292 - accuracy: 0.9693
# Epoch 33/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1904 - accuracy: 0.9573
# Epoch 34/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3768 - accuracy: 0.9243
# Epoch 35/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2543 - accuracy: 0.8797
# Epoch 36/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2782 - accuracy: 0.9429
# Epoch 37/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1828 - accuracy: 0.9688
# Epoch 38/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2360 - accuracy: 0.9393
# Epoch 39/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1240 - accuracy: 1.0000
# Epoch 40/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1947 - accuracy: 0.9720
# Epoch 41/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2623 - accuracy: 0.8781
# Epoch 42/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1488 - accuracy: 0.9365
# Epoch 43/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1225 - accuracy: 0.9649
# Epoch 44/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1578 - accuracy: 0.9826
# Epoch 45/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2145 - accuracy: 0.9273
# Epoch 46/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1130 - accuracy: 0.9941
# Epoch 47/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1447 - accuracy: 0.9629
# Epoch 48/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0799 - accuracy: 0.9961
# Epoch 49/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1748 - accuracy: 0.9447
# Epoch 50/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1140 - accuracy: 1.0000
# Epoch 51/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1200 - accuracy: 0.9447
# Epoch 52/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0624 - accuracy: 0.9961
# Epoch 53/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2240 - accuracy: 0.8720
# Epoch 54/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1999 - accuracy: 0.9547
# Epoch 55/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0934 - accuracy: 0.9547
# Epoch 56/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0449 - accuracy: 0.9892
# Epoch 57/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0904 - accuracy: 0.9862
# Epoch 58/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1076 - accuracy: 0.9447
# Epoch 59/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0921 - accuracy: 0.9892
# Epoch 60/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0806 - accuracy: 0.9918
# Epoch 61/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3828 - accuracy: 0.9365
# Epoch 62/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0403 - accuracy: 1.0000
# Epoch 63/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0806 - accuracy: 0.9673
# Epoch 64/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2225 - accuracy: 0.9309
# Epoch 65/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1165 - accuracy: 0.9447
# Epoch 66/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0880 - accuracy: 0.9629
# Epoch 67/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 68/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1108 - accuracy: 0.9547
# Epoch 69/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0674 - accuracy: 0.9882
# Epoch 70/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0393 - accuracy: 1.0000
# Epoch 71/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0335 - accuracy: 1.0000
# Epoch 72/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0385 - accuracy: 1.00 - 0s 2ms/step - loss: 0.0715 - accuracy: 1.0000
# Epoch 73/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0752 - accuracy: 1.0000
# Epoch 74/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0830 - accuracy: 1.0000
# Epoch 75/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0568 - accuracy: 1.0000
# Epoch 76/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.9780
# Epoch 77/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0392 - accuracy: 1.0000
# Epoch 78/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1139 - accuracy: 0.9826
# Epoch 79/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0442 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0391 - accuracy: 1.0000
# Epoch 81/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1002 - accuracy: 0.9606
# Epoch 82/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0672 - accuracy: 0.9892
# Epoch 83/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0499 - accuracy: 1.0000
# Epoch 84/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1203 - accuracy: 0.9310
# Epoch 85/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0752 - accuracy: 0.9582
# Epoch 86/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0541 - accuracy: 1.0000
# Epoch 87/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0758 - accuracy: 1.0000
# Epoch 88/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0454 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0707 - accuracy: 1.0000
# Epoch 90/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0815 - accuracy: 0.9570
# Epoch 91/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0393 - accuracy: 0.9941
# Epoch 92/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 93/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0350 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1038 - accuracy: 0.9826
# Epoch 95/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0357 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0961 - accuracy: 0.9720
# Epoch 98/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0415 - accuracy: 0.9826
# Epoch 99/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 100/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0572 - accuracy: 1.0000
# Epoch 101/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0560 - accuracy: 0.9787
# Epoch 103/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0400 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0497 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0665 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0426 - accuracy: 1.0000
# Epoch 109/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0506 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 111/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0642 - accuracy: 0.9892
# Epoch 112/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0531 - accuracy: 0.9941
# Epoch 113/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0675 - accuracy: 1.0000
# Epoch 116/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1195 - accuracy: 0.9720
# Epoch 117/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 118/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1138 - accuracy: 0.9447
# Epoch 120/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0266 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0314 - accuracy: 0.9918
# Epoch 123/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0606 - accuracy: 0.9780
# Epoch 124/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1595 - accuracy: 0.9167
# Epoch 125/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0772 - accuracy: 0.9720
# Epoch 127/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0689 - accuracy: 0.9629
# Epoch 128/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0388 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0410 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1028 - accuracy: 0.9661
# Epoch 131/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0803 - accuracy: 0.9862
# Epoch 132/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0280 - accuracy: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0831 - accuracy: 0.9582
# Epoch 135/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0893 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0624 - accuracy: 0.9661
# Epoch 141/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 145/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0314 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0319 - accuracy: 0.9780
# Epoch 156/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1309 - accuracy: 0.9629
# Epoch 158/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2249 - accuracy: 0.9447
# Epoch 159/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0567 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0525 - accuracy: 0.9780
# Epoch 163/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0967 - accuracy: 0.9447
# Epoch 166/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0377 - accuracy: 0.9892
# Epoch 168/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0456 - accuracy: 0.9862
# Epoch 173/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0343 - accuracy: 1.0000
# Epoch 174/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 175/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0491 - accuracy: 0.9720
# Epoch 176/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0301 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 180/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0348 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0513 - accuracy: 0.9780
# Epoch 186/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0539 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1295 - accuracy: 0.9447
# Epoch 194/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 1.00 - 0s 3ms/step - loss: 0.0395 - accuracy: 0.9826
# Epoch 195/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0429 - accuracy: 0.9892
# Epoch 199/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 1.00 - 0s 2ms/step - loss: 0.0207 - accuracy: 1.0000
# model created

# %% [markdown]
# ### Chat Functions for Bot

# %%
model = load_model('chatbot_model.h5')

# %%
def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s:
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res

# %% [markdown]
# ### Build Chat Bot Interface

# %%
def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))

        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')

        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)


base = Tk()
base.title("Hello")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)


#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)

base.mainloop()
